# %%
pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = 'http://www.naver.com/index.html'

# %%
res = urllib.request.urlopen(url)
data = res.read()
#print('data \n', data)

# %%
src = data.decode('utf-8')

# %%
html = BeautifulSoup(src, 'html.parser')
BeautifulSoup(src, 'html.parser')
# Out:
#  <!DOCTYPE html>
# ...

# %%
a = html.find('a')
print('a tag : ', a)
a.string
# Out:
# a tag :  <a href="#topAsideButton"><span>상단영역 바로가기</span></a>
# '상단영역 바로가기'

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
file = open('C:/File_Test/html01.html', mode = 'r', encoding = 'utf-8')
text = file.read()
print(text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title> html5 - 시멘틱 태그 </title>
# </head>
# <body>
#    <h1> 시멘틱 태그 ?</h1>
#    <p> html5에서 웹문서에 의미를 부여하는 태그를 의미 </p>
#    <h2> 주요 시멘틱 태그 </h2>
#    <ul>
#       <li> header : 문서의 머리말(사이트 소개, 제목, 로그 )</li>
#       <li> nav : 네이게이션(메뉴) </li>
#       <li> section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그</li>
#       <li> aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) </li>
#       <li> footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) </li>
#    </ul>
# </body>
# </html>

# %%
html = BeautifulSoup(text, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title> html5 - 시멘틱 태그 </title>
# </head>
# <body>
# <h1> 시멘틱 태그 ?</h1>
# <p> html5에서 웹문서에 의미를 부여하는 태그를 의미 </p>
# <h2> 주요 시멘틱 태그 </h2>
# <ul>
# <li> header : 문서의 머리말(사이트 소개, 제목, 로그 )</li>
# <li> nav : 네이게이션(메뉴) </li>
# <li> section : 웹 문서를 장(chapter)으로 볼 때 절을 구분하는 태그</li>
# <li> aside : 문서의 보조 내용(광고, 즐겨찾기, 링크) </li>
# <li> footer : 문서의 꼬리말(작성자, 저작권, 개인정보보호) </li>
# </ul>
# </body>
# </html>

# %%
html = BeautifulSoup(text, 'html.parser')

h1 = html.html.body.h1
h1.string
# Out:
# ' 시멘틱 태그 ?'

# %%
a = html.find('h1')
print('a tag : ', a)
# Out:
# a tag :  <h1> 시멘틱 태그 ?</h1>

# %%
file = open('C:/File_Test/html02.html', mode = 'r', encoding = 'utf-8')
source = file.read()
print(source)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>선(hr), 줄바꿈(br), 링크(a)</title>
# </head>
# <body>
#   <hr/>
#   <h1> 링크 태그 </h1>
#   <hr/>
#
#   <!-- 링크 태그 -->
#   <!-- 형식) <태그명 속성="값"> 내용 </태그명> -->
#   <a href="www.naver.com">네이버</a>
#   <a href="http://www.naver.com">네이버</a>
#   <br><br> <!-- 줄바꿈 -->
#   <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>
#   <br><br>
#   <a href="www.duam.net">다음</a>
#   <a href="http://www.duam.net">다음</a>
#
# </body>
# </html>

# %%
html = BeautifulSoup(source, 'html.parser')

# %%
links = html.find_all('a')
print('links : ', links)
print('links size = ', len(links))
# Out:
# links :  [<a href="www.naver.com">네이버</a>, <a href="http://www.naver.com">네이버</a>, <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>, <a href="www.duam.net">다음</a>, <a href="http://www.duam.net">다음</a>]
# links size =  5

# %%
for link in links :
    print('link : ', link)
    print('link.attrs : ', link.attrs)
    
    try :
        print(link.attrs['href'])
        print(link.attrs['href'])
        print(link.attrs['target'])
    except Exception as e :
        print('예외 발생 : ', e)
        print()
# Out:
# link :  <a href="www.naver.com">네이버</a>
# link.attrs :  {'href': 'www.naver.com'}
# www.naver.com
# www.naver.com
# 예외 발생 :  'target'
#
# link :  <a href="http://www.naver.com">네이버</a>
# link.attrs :  {'href': 'http://www.naver.com'}
# http://www.naver.com
# http://www.naver.com
# 예외 발생 :  'target'
#
# link :  <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>
# link.attrs :  {'href': 'http://www.naver.com', 'target': '_blank'}
# http://www.naver.com
# http://www.naver.com
# _blank
# link :  <a href="www.duam.net">다음</a>
# link.attrs :  {'href': 'www.duam.net'}
# www.duam.net
# www.duam.net
# 예외 발생 :  'target'
#
# link :  <a href="http://www.duam.net">다음</a>
# link.attrs :  {'href': 'http://www.duam.net'}
# http://www.duam.net
# http://www.duam.net
# 예외 발생 :  'target'

# %%
import re

patt = re.compile('http://')
links = html.find_all(href = patt)
print(links)
# Out:
# [<a href="http://www.naver.com">네이버</a>, <a href="http://www.naver.com" target="_blank">네이버 새창으로</a>, <a href="http://www.duam.net">다음</a>]

# %%
for link in links :
    print(link.string)
    print(link.attrs['href'])
# Out:
# 네이버
# http://www.naver.com
# 네이버 새창으로
# http://www.naver.com
# 다음
# http://www.duam.net

# %%
file = open('C:/File_Test/html03.html', mode = 'r', encoding = 'utf-8')
source = file.read()
print(source)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>id/class 선택자, 표 꾸미기</title>
# <style type="text/css">
#   table{
#      border-collapse : collapse; /* 중복 테두리 제거 */
#      border : 3px solid black; /* 테두리 굵기 실선 색 */
#      width: 80%; /* 화면 전체 폭 */
#      text-align: center;  /* 텍스트 정렬 방식 */
#   }
#   tr{
#      height: 24px;  /* 줄 간격 */
#      font-size: 13px; /* 글자 크기 */
#   }
#   /* 행 위에 마우스 오버 시 */
#   tr:hover{
#      color: #ffffff; /* 글자색 흰색 */
#      font-weight: bold; /* 굵게 */
#      background-color: #00ccff; /* 배경색 : 하늘색 계열 */
#      cursor: pointer;  /* 커서 모양 변경 */
#   }
#   /* 표 제목 열 스타일 적용 */
#   th{
#      height: 25px;
#      font-size: 14px;
#      background-color: #e0bbd2; /* RGB 색상표 - NAVER */
#   }
#   /* 형식 : #id이름{ 속성 : 값; } - 이름 중복 불가능 */
#   #id{width : 15%}
#   #name{width: 10%}
#   #major{width: 25%}
# ...

# %%
html = BeautifulSoup(source, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>id/class 선택자, 표 꾸미기</title>
# <style type="text/css">
#   table{
#      border-collapse : collapse; /* 중복 테두리 제거 */
#      border : 3px solid black; /* 테두리 굵기 실선 색 */
#      width: 80%; /* 화면 전체 폭 */
#      text-align: center;  /* 텍스트 정렬 방식 */
#   }
#   tr{
#      height: 24px;  /* 줄 간격 */
#      font-size: 13px; /* 글자 크기 */
#   }
#   /* 행 위에 마우스 오버 시 */
#   tr:hover{
#      color: #ffffff; /* 글자색 흰색 */
#      font-weight: bold; /* 굵게 */
#      background-color: #00ccff; /* 배경색 : 하늘색 계열 */
#      cursor: pointer;  /* 커서 모양 변경 */
#   }
#   /* 표 제목 열 스타일 적용 */
#   th{
#      height: 25px;
#      font-size: 14px;
#      background-color: #e0bbd2; /* RGB 색상표 - NAVER */
#   }
#   /* 형식 : #id이름{ 속성 : 값; } - 이름 중복 불가능 */
#   #id{width : 15%}
#   #name{width: 10%}
#   #major{width: 25%}
# ...

# %%
table = html.select_one('#tab')

# %%
ths = table.find_all('th')
print(ths)

for th in ths :
    print(th.string)
# Out:
# [<th id="id"> 학번 </th>, <th id="name"> 이름 </th>, <th id="major"> 학과 </th>, <th id="email"> 이메일 </th>]
#  학번
#  이름
#  학과
#  이메일

# %%
table = html.select_one('#tab > tr > th')
print(table)
# Out:
# <th id="id"> 학번 </th>

# %%
ths = table.find_all('th')
print(ths)

for th in ths :
    print(th.string)
# Out:
# []

# %%
table = html.select_one('#tab > .odd')
print(table)
# Out:
# <tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>

# %%
ths = table.find_all('th')
print(ths)

for th in ths :
    print(th.string)
# Out:
# []

# %%
trs = html.select('#tab > .odd')
# print(trs)
for tr in trs :
    tds = tr.find_all('td')
    for td in tds :
        print(td.string)
 #   print(tr.string)
# Out:
#  201602
#  이순신
#  해양학과
#  lee@naver.com
#  201604
#  유관순
#  유아교육
#  you@naver.com

# %%
trs = html.select("tr[class=odd]")
print(trs)
# Out:
# [<tr class="odd"> <!-- 3행(홀수) -->
# <td> 201602 </td>
# <td> 이순신 </td>
# <td> 해양학과 </td>
# <td> lee@naver.com </td>
# </tr>, <tr class="odd"> <!-- 5행 -->
# <td> 201604 </td>
# <td> 유관순 </td>
# <td> 유아교육 </td>
# <td> you@naver.com </td>
# </tr>]

# %%
import urllib.request as req
from bs4 import BeautifulSoup

# %%
url = "http://media.daum.net"

# %%
req.urlopen(url)

# %%
res = req.urlopen(url)

# %%
source = res.read()
print(source)
# Out:
# b'\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum \xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:title" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4 | \xed\x99\x88"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:url" content="https://news.daum.net/" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4 | \xed\x99\x88</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/ne
# ...

# %%
sr = source.decode('utf-8')
print(sr)
# Out:
# <!DOCTYPE html>
#
#
#
# <html lang="ko" class="os_unknown none unknown version_0 ">
# <head>
# <meta charset="utf-8">
# <meta name="referrer" content="always" />
#
# <meta property="og:author" content="Daum 뉴스" />
# <meta property="og:site_name" content="다음뉴스" />
# <meta property="og:title" content="다음뉴스 | 홈"/>
# <meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />
# <meta property="og:description" content="다음뉴스" />
# <meta property="og:url" content="https://news.daum.net/" />
# <link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#
# <title>다음뉴스 | 홈</title>
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/56c4cce/style.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/56c4cce/calendar.css.merged.css" />
#
# <!--[if lte IE 8]>
# ...

# %%
html = BeautifulSoup(sr, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="다음뉴스 | 홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>다음뉴스 | 홈</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/56c4cce/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/56c4cce/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
atags = html.select('.link_txt')
print(atags)
# Out:
# [<a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20240723160401289&amp;clusterId=5590543,5590550,5889434,5150099,5000023,210039&amp;clusterTitle=[언론사픽] 주요뉴스,[언론사픽] 기획뉴스,IT,섹션 실시간뉴스-IT,과학,[서울신문 나우뉴스] 핵잼 사이언스&amp;keywordType=NONE,NONE,NONE,NONE,INTEREST,NONE" data-tiara-id="20240723160401289" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20240723160401289">
#                                     마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]
#                                 </a>, <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20240723151737203&amp;clusterId=5590543,1691335&amp;clusterTitle=[언론사픽] 주요뉴스,전라북도&amp;keywordType=NONE,NONE" data-tiara-id="20240723151737203" data-tiara-layer="article_main" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://v.daum.net/v/20240723151737203">
#                                     반려견·반려묘 한 해 11만 마리 버려진다.."27.6% 자연사·18% 안락사"
# ...

# %%
print('a tags 수 = ', len(atags))
# Out:
# a tags 수 =  45

# %%
crawling_datas = []
cnt = 0
for atag in atags :
    cnt += 1
    atagStr = str(atag.string)
    print(cnt, '->', atagStr)
    crawling_data = crawling_datas.append(atagStr.strip())
    print(crawling_datas)
# Out:
# 1 ->
#                                     마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]
#
# ['마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]']
# 2 ->
#                                     반려견·반려묘 한 해 11만 마리 버려진다.."27.6% 자연사·18% 안락사"
#
# ['마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]', '반려견·반려묘 한 해 11만 마리 버려진다.."27.6% 자연사·18% 안락사"']
# 3 ->
#                                     폐지 팔아 5년째 성금.. 81살 홍경식 씨 올해도 기부
#
# ['마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]', '반려견·반려묘 한 해 11만 마리 버려진다.."27.6% 자연사·18% 안락사"', '폐지 팔아 5년째 성금.. 81살 홍경식 씨 올해도 기부']
# 4 ->
#                                     포천 폭우·강풍에... 수령 230여년 '천연기념물 오리나무' 쓰러져
#
# ['마약먹은 미친 상어?…브라질 해안 상어 잡아보니 ‘코카인’ 양성 반응 [핵잼 사이언스]', '반려견·반려묘 한 해 11만 마리 버려진다.."27.6% 자연사·18% 안락사"', '폐지 팔아 5년째 성금.. 81살 홍경식 씨 올해도 기부', "포천 폭우·강풍에... 수령 230여년 '천연기념물 오리나무' 쓰러져"]
# 5 ->
#                                     코스피, 0.39%↑ 마감…카카오 '노답'
#
# ...

# %%
file = open('C:/File_Test/data/crawling_data.txt', mode='w', encoding='ms949')
file.write(str(crawling_datas))
file.close()

# %%
import pickle

# %%
file = open('C:/File_Test/data/data.pickle', mode='wb')
pickle.dump(crawling_datas, file)
print(file)
# Out:
# <_io.BufferedWriter name='C:/File_Test/data/data.pickle'>

# %%
file = open('C:/File_Test/data/data.pickle', mode='rb')

# %%
crawling_data = pickle.load
print(crawling_data)
# Out:
# <built-in function load>

# %%
import re

# %%
def clean_text(text_string) :
    # 문장부호 제거
    texts_re = re.sub('[,.?!:;]', ' ', text_string)
    # 특수문자, 숫자 제거
    texts_re = re.sub('[@#$%^&]|[0-9]', ' ', texts_re)
    # 영문자 제거 : 소문자로 변경 -> 제거
    texts_re = texts_re.lower()
    texts_re = re.sub('[a-z]', ' ', texts_re)
    # 공백 제거
    texts_re = ' '.join(texts_re.split()) # 한칸 이상의 공백을 한칸으로
    return texts_re

# %%
clean_texts = [clean_text(row) for row in crawling_datas]

# %%
word_count = {}
for text in clean_texts :
    for word in text.split() :
        print('word = ', word)
        word_count[word] = word_count.get(word, 0) + 1
        print()

print(word_count)
# Out:
# word =  마약먹은
#
# word =  미친
#
# word =  상어
#
# word =  …브라질
#
# word =  해안
#
# word =  상어
#
# word =  잡아보니
#
# word =  ‘코카인’
#
# word =  양성
#
# word =  반응
#
# word =  [핵잼
#
# word =  사이언스]
#
# word =  반려견·반려묘
#
# word =  한
#
# word =  해
#
# word =  만
#
# word =  마리
#
# word =  버려진다
#
# word =  "
#
# word =  자연사·
#
# word =  안락사"
#
# word =  폐지
#
# word =  팔아
#
# word =  년째
#
# word =  성금
#
# word =  살
#
# word =  홍경식
#
# word =  씨
#
# word =  올해도
#
# word =  기부
#
# word =  포천
#
# word =  폭우·강풍에
#
# word =  수령
#
# word =  여년
#
# word =  '천연기념물
#
# word =  오리나무'
#
# word =  쓰러져
#
# word =  코스피
#
# word =  ↑
#
# word =  마감…카카오
#
# word =  '노답'
#
# word =  김영란법
#
# word =  식사비
#
# word =  이르면
#
# word =  추석
#
# word =  전에
#
# word =  만원→
#
# word =  만원으로
#
# word =  오른다
#
# word =  추경호
#
# word =  “윤석열
#
# word =  ”
#
# word =  “똘똘
#
# word =  뭉치자
#
# word =  ”
#
# word =  연호하며
#
# word =  ‘단결’
#
# word =  호소
#
# word =  의대
#
# word =  교수들
#
# word =  "지방
#
# word =  전공의
#
# word =  수도권
# ...

# %%
new_word_count = {}
for word, cnt in word_count.items() :
    if cnt >= 2 and len(word) >= 2 :
        new_word_count[word] = new_word_count.get(word, cnt)
print(new_word_count)
# Out:
# {'마약먹은': 2, '미친': 2, '상어': 4, '…브라질': 2, '해안': 2, '잡아보니': 2, '‘코카인’': 2, '양성': 2, '반응': 2, '[핵잼': 2, '사이언스]': 2}

# %%
from collections import Counter

counter = Counter(new_word_count)
top2_word = counter.most_common(2)
print(top2_word)
# Out:
# [('상어', 4), ('마약먹은', 2)]

# %%
words = []
counts = []

for word, count in top2_word :
    words.append(word)
    counts.append(count)

# %%
print(words)
print(counts)
# Out:
# ['상어', '마약먹은']
# [4, 2]

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as font_manager, rc

# %%
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.bar(words, counts)
plt.show()
